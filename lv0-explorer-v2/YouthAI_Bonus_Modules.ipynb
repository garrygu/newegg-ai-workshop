# %% [markdown]
# # 🎁 YouthAI Bonus Module Pack
#
# **Extra AI Activities for Extended Learning!** ✨
#
# Welcome to your bonus AI exploration activities! Each module takes about 15–30 minutes and helps you explore new, fun aspects of AI — without needing coding.
#
# These are **optional activities** you can do:
# - After completing the main workshop
# - As homework between classes
# - For extra credit
# - Just for fun!
#
# ---
#
# ## 📋 Module List
#
# 1. [AutoDraw: AI Drawing Challenge](#autodraw)
# 2. [Teachable Machine: Train Your Own Classifier](#teachable-machine)
# 3. [Advanced Image Styles](#advanced-styles)
# 4. [AI Music Creation](#music)
# 5. [AI Comic Strip Creator](#comic)
# 6. [Translation Deep Dive](#translation)
# 7. [Deepfake Awareness](#deepfakes)
# 8. [AI for Good Projects](#ai-for-good)
# 9. [Team Collaboration Challenge](#team-project)
#
# ---

# %% [markdown]
# # 🎨 Module 1: AutoDraw - AI Drawing Challenge {#autodraw}
#
# **Goal:** Experience AI-powered drawing recognition and assistance!
#
# **Time:** 20 minutes
#
# ## What is AutoDraw?
#
# **AutoDraw** is Google's AI tool that guesses what you're drawing and helps you create better artwork!
#
# [👉 Try AutoDraw](https://autodraw.com/)
#
# ---
#
# ## Activity: Let AI Finish Your Drawing
#
# **How to Use:**
# 1. Open the link above
# 2. Draw anything you like — a cat, a car, a pizza, a robot!
# 3. Watch as Google's AI guesses what you might be drawing
# 4. Click on AI suggestions to see your drawing improve!
#
# **Try These Drawings:**
# - □ A simple house
# - □ A smiling face
# - □ A flower
# - □ A robot
# - □ A star
# - □ Something of your choice!
#
# ---
#
# ## Challenge: Can You "Fool" the AI? 🤔
#
# **Try this experiment:**
#
# 1. Draw something creative and unusual
# 2. See if the AI can still guess it
# 3. Try drawing from different angles
# 4. Use abstract shapes and see what happens!
#
# **My Creative Drawing:**
# ```
# What did you draw?
# [Describe your unusual drawing]
#
# Could the AI guess it? Yes / No
#
# What did the AI think you were drawing?
# [Describe the AI's guesses]
# ```
#
# ---
#
# ## Reflection Questions:
#
# 1. **What does this tell you about how AI understands shapes?**
#    ```
#    [Your observations]
#    ```
#
# 2. **When was the AI most accurate? Least accurate?**
#    ```
#    [When did it work well? When did it struggle?]
#    ```
#
# 3. **How is AutoDraw different from text-to-image generators?**
#    ```
#    [Compare AutoDraw vs DALL·E/Stable Diffusion]
#    ```
#
# ---

# %% [markdown]
# # 🧠 Module 2: Train Your Own AI Classifier {#teachable-machine}
#
# **Goal:** Learn how AI learns from examples!
#
# **Time:** 30 minutes
#
# ## What is Teachable Machine?
#
# With **Teachable Machine**, you can train your own AI model to recognize things — just like the professionals do!
#
# [👉 Open Teachable Machine](https://teachablemachine.withgoogle.com/)
#
# ---
#
# ## Step-by-Step: Create Your Image Classifier
#
# ### **Step 1: Set Up Your Project**
# 1. Click "Get Started"
# 2. Choose "Image Project"
# 3. Select "Standard image model"
#
# ### **Step 2: Create Two Categories**
# Pick two things to classify. Examples:
# - ✏️ Pencil vs 📱 Phone
# - 🐱 Cat vs 🐶 Dog
# - 🍎 Apple vs 🍌 Banana
# - 🤖 Robot vs 🚗 Car
# - [Your choice:] __________ vs __________
#
# ### **Step 3: Train Each Category**
# 1. Click on "Class 1" → Name it (e.g., "Pencil")
# 2. Click "Webcam" or "Upload" to add 20-30 images
# 3. Repeat for "Class 2" (e.g., "Phone")
# 4. Add variety: different angles, lighting, backgrounds
#
# ### **Step 4: Train Your Model**
# - Click "Train Model"
# - Wait 1-2 minutes
# - Watch the magic happen! ✨
#
# ### **Step 5: Test It!**
# - Show new objects to your webcam
# - See if your AI can classify them correctly!
#
# ---
#
# ## Your Training Results:
#
# **Category 1:** ___________
# - Number of training images: _______
# - Description:
#
# **Category 2:** ___________
# - Number of training images: _______
# - Description:
#
# **Test Results:**
# ```
# Correct classifications: ___ out of 10 tries
# ```
#
# ---
#
# ## Experiment: What Happens with Fewer Examples?
#
# **Try This:**
#
# 1. **First Test:** Train with 30 images per category
# 2. **Second Test:** Train with only 5 images per category
# 3. **Compare:** Which works better?
#
# **Your Observations:**
# ```
# With 30 images:
# [How accurate was it?]
#
# With 5 images:
# [How accurate was it?]
#
# What did you notice?
# [Your findings]
# ```
#
# ---
#
# ## Challenge: Creative Classifier
#
# **Create an unusual classifier:**
#
# Instead of common objects, try classifying:
# - 😊 Happy faces vs 😢 Sad faces
# - 🌞 Daytime scenes vs 🌙 Nighttime scenes
# - 🎨 Drawings vs 📷 Photos
# - [Your creative idea:]
#
# **My Creative Classifier:**
# ```
# Category 1: ___________
# Category 2: ___________
#
# Why did I choose these?
# [Your reasoning]
#
# How well did it work?
# [Your results]
# ```
#
# ---

# %% [markdown]
# # 🎨 Module 3: Advanced Image Style Experiments {#advanced-styles}
#
# **Goal:** Master different art styles with AI!
#
# **Time:** 25 minutes
#
# ## Challenge: Style Master
#
# Create the SAME subject in 5 different styles!
#
# **Your Subject:** ___________
#
# ---
#
# **Style 1 - Cartoon:**
# ```
# Prompt: [Your subject] + cute cartoon style, vibrant colors, simple shapes
# ```
#
# **Style 2 - Realistic:**
# ```
# Prompt: [Your subject] + photorealistic, highly detailed, professional photography
# ```
#
# **Style 3 - Watercolor:**
# ```
# Prompt: [Your subject] + watercolor painting, soft colors, artistic brush strokes
# ```
#
# **Style 4 - Sci-Fi:**
# ```
# Prompt: [Your subject] + futuristic, neon lights, cyberpunk style, glowing effects
# ```
#
# **Style 5 - Anime:**
# ```
# Prompt: [Your subject] + anime style, Japanese animation, expressive eyes, dynamic pose
# ```
#
# **Which style was your favorite?** ___________
#
# **What surprised you most?**
# ```
# [Your observations about how style affects the image]
# ```
#
# ---

# %% [markdown]
# # 🎵 Module 4: AI Music Creation {#music}
#
# **Goal:** Create your own AI-generated background music!
#
# **Time:** 20 minutes
#
# ## Tools to Try:
#
# ### Option 1: **Suno AI**
# [👉 Try Suno AI](https://suno.ai)
#
# ### Option 2: **Soundraw**
# [👉 Try Soundraw](https://soundraw.io/)
#
# ### Option 3: **Mubert**
# [👉 Try Mubert](https://mubert.com)
#
# ---
#
# ## Activity: Create Background Music
#
# **Step 1:** Pick a music style:
# - □ Happy and upbeat
# - □ Calm and relaxing
# - □ Epic and adventurous
# - □ Mysterious and suspenseful
# - □ Futuristic and electronic
#
# **Step 2:** Type a short idea:
# ```
# Example: "A happy robot dance tune with electronic beats"
# Your idea: [Write your music prompt]
# ```
#
# **Step 3:** Generate and listen!
#
# ---
#
# ## Challenge: Theme Song for Your Story
#
# Create a 20-30 second theme song for your AI video story!
#
# **My Theme Song:**
# - Music Style: ___________
# - Mood: ___________
# - Why it fits my story: ___________
#
# ---
#
# ## Reflection:
#
# **How does AI know what music "feels" like?**
# ```
# [Think about how AI learns patterns in music]
# ```
#
# ---

# %% [markdown]
# # 📖 Module 5: AI Comic Strip Creator {#comic}
#
# **Goal:** Create a 3-panel comic using AI!
#
# **Time:** 30 minutes
#
# ## Tools:
# - [Canva](https://www.canva.com)
# - ChatGPT for story ideas
# - DALL·E for images
#
# ---
#
# ## Activity: Create Your Comic
#
# ### Step 1: Plan Your Comic Story
#
# **Use ChatGPT:**
# > "Write a simple 3-panel comic story about [your idea]. Include dialogue for each panel."
#
# **My Comic Story:**
# ```
# Panel 1: [What happens?]
# Dialogue: [What do characters say?]
#
# Panel 2: [What happens?]
# Dialogue: [What do characters say?]
#
# Panel 3: [What happens?]
# Dialogue: [What do characters say?]
# ```
#
# ---
#
# ### Step 2: Generate Images
#
# Create 3 images (one for each panel) using DALL·E
#
# **Panel 1 Prompt:**
# ```
# [Your detailed prompt]
# ```
#
# **Panel 2 Prompt:**
# ```
# [Your detailed prompt]
# ```
#
# **Panel 3 Prompt:**
# ```
# [Your detailed prompt]
# ```
#
# ---
#
# ### Step 3: Assemble in Canva
#
# 1. Open Canva
# 2. Search for "Comic Strip" templates
# 3. Upload your 3 images
# 4. Add text bubbles with dialogue
# 5. Add a title!
#
# **My Comic Title:** "___________"
#
# ---
#
# ## Challenge: "My Robot Day"
#
# Create a comic titled "My Robot Day" showing a day in the life of a friendly robot!
#
# ---

# %% [markdown]
# # 🌍 Module 6: Translation Deep Dive {#translation}
#
# **Goal:** Understand how AI handles different languages!
#
# **Time:** 20 minutes
#
# ## Activity: Translation Challenge
#
# [👉 Try DeepL Translator](https://www.deepl.com/translator)
#
# ---
#
# ## Experiment 1: Round-Trip Translation
#
# **My Original Text (English):**
# ```
# [Write 2-3 sentences about AI]
# ```
#
# **Step 1:** Translate to another language
# **Language:** ___________
#
# **Step 2:** Translate back to English
#
# **Result:**
# ```
# [What came back?]
# ```
#
# **What changed?**
# ```
# [Compare original vs. result]
# ```
#
# ---
#
# ## Experiment 2: Idioms and Expressions
#
# Try translating these expressions:
# - "It's raining cats and dogs"
# - "Break a leg"
# - "Piece of cake"
#
# **What happens?**
# ```
# [Does the AI understand the meaning or translate literally?]
# ```
#
# ---
#
# ## Reflection:
#
# **What challenges might AI face in understanding culture?**
# ```
# [Think about jokes, idioms, expressions]
# ```
#
# ---

# %% [markdown]
# # 🕵️ Module 7: Deepfake Awareness Project {#deepfakes}
#
# **Goal:** Learn to spot AI-generated fake images and understand why it matters!
#
# **Time:** 25 minutes
#
# ## Activity 1: Which Face Is Real?
#
# [👉 Try "Which Face Is Real?" Game](https://www.whichfaceisreal.com/)
#
# **How to Play:**
# 1. Visit the website — look at the two faces shown
# 2. Guess: which one is real, which one is AI-generated?
# 3. Click to reveal the answer
# 4. Try 10 examples and see how many you get right!
#
# **Your Results:**
# ```
# Correct guesses: ___ out of 10
# ```
#
# ---
#
# ## Activity 2: Create Awareness Poster
#
# Use Canva or draw on paper to create a poster that teaches others about deepfakes!
#
# **Poster Elements:**
# - □ What are deepfakes?
# - □ Why should we be careful?
# - □ How to spot fake images?
# - □ A catchy slogan!
#
# **My Poster Idea:**
# ```
# [Sketch or describe your poster]
# ```
#
# **My Slogan:**
# ```
# [Create a catchy phrase about deepfakes]
# ```
#
# ---
#
# ## Discussion Questions:
#
# 1. **How might fake images/videos be used for good?**
#    - Entertainment (movies, games)
#    - Education (historical recreations)
#    - Art and creativity
#
# 2. **How might fake images/videos be used for bad?**
#    - Spreading misinformation
#    - Fake news
#    - Impersonating people
#
# 3. **What rules or safeguards should exist?**
#    ```
#    [Your suggestions]
#    ```
#
# ---

# %% [markdown]
# # 💡 Module 8: AI for Good Projects {#ai-for-good}
#
# **Goal:** Design AI solutions for real-world problems!
#
# **Time:** 30 minutes
#
# ## Activity: Brainstorm with AI
#
# [👉 Open ChatGPT](https://chat.openai.com/?model=gpt-4o)
#
# ### Step 1: Generate Ideas
#
# **Ask ChatGPT:**
# > "Give me 5 creative ideas for how AI can help [choose: environment / healthcare / education / accessibility]"
#
# **AI's Ideas:**
# ```
# 1.
# 2.
# 3.
# 4.
# 5.
# ```
#
# ---
#
# ### Step 2: Design Your "AI for Good" Project
#
# Pick your favorite idea and develop it!
#
# **Project Template:**
#
# **Problem:** What problem does your project solve?
# ```
# [Describe the real-world problem]
# ```
#
# **Solution:** How can AI help?
# ```
# [Your AI-powered solution]
# ```
#
# **Impact:** Who would benefit?
# ```
# [Who would be helped?]
# ```
#
# **How it works:**
# ```
# [Simple explanation of your AI solution]
# ```
#
# **Project Name:** ___________
#
# **Project Slogan:** ___________
#
# ---
#
# ### Step 3: Create a Pitch!
#
# **1-Minute Pitch:**
# ```
# [Write your elevator pitch explaining:
# - The problem
# - How AI solves it
# - Who it helps
# - Why it matters]
# ```
#
# ---
#
# ## Bonus: Visualize Your Idea
#
# Use DALL·E to create an image showing your "AI for Good" project in action!
#
# **Image Prompt:**
# ```
# [Describe your AI solution as an image]
# ```
#
# ---

# %% [markdown]
# # 🤝 Module 9: Team Collaboration Challenge {#team-project}
#
# **Goal:** Work together to create a team AI project!
#
# **Time:** Extended activity (can be homework)
#
# ## Team Story Project
#
# **Team Theme:** "A Day with Our AI Helper"
#
# ---
#
# ### Team Roles:
#
# **Writer** — Creates the story outline and scripts
# **Visual Artist** — Creates images and videos
# **Voice Director** — Creates audio and narration
# **Editor** — Combines everything together
#
# ---
#
# ### Team Members:
#
# 1. Name: ___________ Role: ___________
# 2. Name: ___________ Role: ___________
# 3. Name: ___________ Role: ___________
# 4. Name: ___________ Role: ___________
#
# ---
#
# ### Team Story Plan:
#
# **Story Outline:**
# ```
# [Your team's story together]
# ```
#
# **Team Storyboard:**
#
# | Scene | What Happens | Who Creates | Status |
# |-------|--------------|-------------|--------|
# | 1 | | | □ |
# | 2 | | | □ |
# | 3 | | | □ |
# | 4 | | | □ |
#
# ---
#
# ### Team Checklist:
#
# - □ Story planned as a team
# - □ Work divided among members
# - □ Individual pieces created
# - □ Team assembled final story
# - □ Story ready to share!
#
# ---
#
# ## Team Presentation:
#
# Present your collaborative story to the class!
#
# **Presentation includes:**
# 1. Introduce your team
# 2. Share your process
# 3. Show your story
# 4. Answer questions
#
# ---

# %% [markdown]
# # 🎉 Bonus Modules Complete!
#
# Great job exploring these extra AI activities!
#
# ## What You've Explored:
#
# - ✅ AI-assisted drawing
# - ✅ Training your own AI models
# - ✅ Advanced image styles
# - ✅ AI music creation
# - ✅ Comic strip creation
# - ✅ Translation challenges
# - ✅ Deepfake awareness
# - ✅ AI for Good projects
# - ✅ Team collaboration
#
# ---
#
# ## Keep Exploring!
#
# These are just the beginning! There are so many AI tools and possibilities to explore:
#
# **More Tools to Try:**
# - AI code assistants (GitHub Copilot)
# - AI video editors (Descript, Runway)
# - AI writing tools (Jasper, Copy.ai)
# - AI design tools (Figma AI, Adobe Firefly)
#
# **Next Steps:**
# - Move to Beginner Level to learn coding!
# - Create your own AI projects
# - Share your creations with others
# - Keep learning and experimenting!
#
# ---
#
# > 💡 **Remember:** The best way to learn AI is by doing! Keep creating, keep experimenting, and have fun! 🚀✨
