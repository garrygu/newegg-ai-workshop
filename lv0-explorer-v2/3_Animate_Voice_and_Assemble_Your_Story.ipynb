# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/garrygu/newegg-ai-workshop/blob/main/lv0-explorer-v2/3_Animate_Voice_and_Assemble_Your_Story.ipynb)

# %% [markdown]
# # 🎬 Animate, Voice & Assemble Your Story
#
# **Bring Your Story to Life!** 🎥✨
#
# In this final session, you'll learn to animate your images and assemble everything into your complete multimedia story using Canva's built-in tools!
#
# ---
#
# ## ⏱️ Session Overview
# **Total Time:** 2.5-3 hours
# **Break Time:** 15 minutes
# **Active Learning:** ~2.5 hours
#
# ### 📅 Suggested Schedule:
# - **00:00-00:10** - Welcome & Review Class 2 (10 min)
# - **00:10-00:55** - Learn & Create AI Videos (45 min)
# - **00:55-01:10** - BREAK ☕ (15 min)
# - **01:10-02:40** - Assemble Your Story in Canva (90 min) ⭐ Main focus!
# - **02:40-03:00** - Story Showcase (20 min)
# - **03:00-03:10** - Final Reflection & Celebration (10 min)
#
# ---
#
# ## 🎯 Goals
#
# **By the end of this class, you will:**
# - 🎬 Animate your images into videos using AI
# - 🎤 Add AI voices using Canva's built-in text-to-speech
# - 🎨 Assemble everything into a complete story
# - 🎉 Present your final 1-2 minute AI story!
# - 🧠 Reflect on your AI learning journey
#
# ---
#
# ## 📋 Table of Contents
# 1. [Quick Asset Review](#review)
# 2. [AI Video Animation](#video)
# 3. [Assemble Your Story in Canva](#assemble)
# 4. [Story Showcase](#showcase)
# 5. [Reflection & Celebration](#reflection)
# 6. [BONUS: Advanced Options](#bonus)
#
# ---

# %% [markdown]
# ## 📦 Quick Asset Review {#review}
#
# ### Do You Have Everything From Class 2?
#
# Let's make sure you're ready!
#
# **✅ Check Your `my_ai_story` Folder:**
#
# **Images Created:**
# ```
# □ scene_1.png
# □ scene_2.png
# □ scene_3.png
# □ scene_4.png (if applicable)
# □ scene_5.png (if applicable)
# □ title_card.png (optional)
# ```
#
# **Storyboard:**
# ```
# □ I have my storyboard from Class 2
# □ I know what happens in each scene
# □ I have my voice scripts written
# ```
#
# ---
#
# ### 🚨 Missing Something?
#
# **No problem!** You have options:
#
# 1. **Quick create now** - Use DALL·E to create missing images
# 2. **Simplify your story** - Use fewer scenes (3 scenes minimum)
# 3. **Use still images** - Not all scenes need to be animated
#
# **Remember:** A simple, complete story is better than a complex, unfinished one!
#
# ---

# %% [markdown]
# # PART 1: AI Video Animation 🎬 {#video}
#
# ## 🎥 What is AI Video Animation?
#
# AI video animation turns your **still images into moving videos**!
#
# **What it can do:**
# - Make characters move or gesture
# - Add camera movements (zoom, pan)
# - Create smooth transitions
# - Bring static scenes to life!
#
# **Example:**
# - Still image of a robot → Video of robot waving its hand!
#
# ---
#
# ## 🛠️ Tool: Runway ML
#
# [👉 Open Runway ML](https://app.runwayml.com)
#
# **Why Runway ML?**
# - ✅ Easy to use
# - ✅ Great quality animations
# - ✅ Free tier available
# - ✅ Fast generation (30-60 seconds)
# - ✅ Animate YOUR specific images from Class 2!
#
# ---
#
# ## 📚 How to Use Runway ML
#
# ### Step 1: Set Up Account
# 1. Go to [Runway ML](https://app.runwayml.com)
# 2. Sign up or log in
# 3. You'll get free credits to start!
#
# ---
#
# ### Step 2: Upload Your Image
# 1. Click on **"Image to Video"** or **"Gen-3 Alpha"**
# 2. Upload one of your story scene images
# 3. The system will load your image
#
# ---
#
# ### Step 3: Add Motion Prompt (Optional)
#
# You can describe how you want the image to move!
#
# **Motion Prompt Examples:**
# ```
# "The robot waves hello with its hand"
# "Camera slowly zooms in"
# "Character looks around curiously"
# "Gentle camera pan across the scene"
# "Character nods and smiles"
# ```
#
# **OR leave it blank** for automatic animation!
#
# ---
#
# ### Step 4: Generate Video
# 1. Click **"Generate"**
# 2. Wait 30-60 seconds
# 3. Watch your image come to life!
# 4. Download the video
#
# **Default:** Videos are 4-5 seconds long (perfect!)
#
# ---
#
# ## 💡 Alternative Tools
#
# If Runway ML isn't available:
#
# **Pika Labs** (requires Discord)
# [👉 Try Pika Labs](https://pika.art)
#
# **Stable Animation** (more technical)
# [👉 Try Stable Animation](https://huggingface.co/spaces/ByteDance/AnimateDiff-Lightning)
#
# ---
#
# ## 🎯 Create Your Videos!
#
# **You don't need to animate ALL your scenes!**
# - Animate 2-3 key scenes
# - Use still images for others (totally fine!)
#
# ---
#
# ### **Video 1: [Scene Name]**
#
# **Which image are you animating?**
# ```
# [Example: scene_1.png - Robot introduction]
# ```
#
# **Motion prompt (if using one):**
# ```
# [Example: "The robot waves hello with its hand"]
# OR
# [Leave blank for automatic]
# ```
#
# **Generate the video!**
#
# **✅ Save as:** `scene_1_video.mp4` in `my_ai_story/videos/`
#
# **How did it turn out?**
# ```
# [Perfect? Try again? What would you change?]
# ```
#
# ---
#
# ### **Video 2: [Scene Name]**
#
# **Which image are you animating?**
# ```
# [Your scene]
# ```
#
# **Motion prompt:**
# ```
# [Your motion description or blank]
# ```
#
# **Generate the video!**
#
# **✅ Save as:** `scene_X_video.mp4` in `my_ai_story/videos/`
#
# ---
#
# ### **Video 3: [Scene Name] (Optional)**
#
# **Which image are you animating?**
# ```
# [Your scene]
# ```
#
# **Motion prompt:**
# ```
# [Your motion description or blank]
# ```
#
# **Generate the video!**
#
# **✅ Save as:** `scene_X_video.mp4` in `my_ai_story/videos/`
#
# ---
#
# ## ✅ Video Creation Checklist
#
# - □ Created 2-3 animated video clips (OR decided to use still images)
# - □ All videos saved to `my_ai_story/videos/` folder (if created)
# - □ Files named clearly: `scene_1_video.mp4`, etc.
# - □ Ready to move to Canva!
#
# **Total videos created: ___**
#
# ---
#
# ## 💡 Pro Tips
#
# **✅ DO:**
# - Keep motion prompts simple and clear
# - Animate your most important scenes
# - Test one first before doing all of them
# - Remember: still images work great too!
#
# **❌ DON'T:**
# - Try to animate every single scene (not necessary!)
# - Write complex motion prompts (AI struggles)
# - Worry about perfection (good is great!)
# - Spend too much time here - save it for assembly!
#
# ---

# %% [markdown]
# # PART 2: Assemble Your Story in Canva 🎨 {#assemble}
#
# ## 🎬 It's Assembly Time!
#
# Now we'll put everything together IN ONE TOOL - Canva has everything you need!
#
# **What you have:**
# - ✅ Images from Class 2
# - ✅ Videos from Part 1 (if you made them)
# - ✅ Your storyboard with scripts
#
# **What Canva will do:**
# - 📦 Combine all your visuals
# - 🎤 Generate AI voices from your script (built-in!)
# - 🎵 Add music (optional)
# - 🎬 Create your final video!
#
# ---
#
# ## 🛠️ Tool: Canva Video Editor
#
# [👉 Open Canva](https://www.canva.com)
#
# **Why Canva?**
# - ✅ Super easy to use
# - ✅ Drag and drop interface
# - ✅ Free version works great
# - ✅ **Built-in AI text-to-speech** (no extra tool needed!)
# - ✅ Can combine images, videos, and audio
# - ✅ Professional-looking results
#
# ---
#
# ## 📚 Step-by-Step Assembly Guide
#
# ### **Step 1: Create New Video Project**
#
# 1. Go to [Canva](https://www.canva.com)
# 2. Click **"Create a design"**
# 3. Select **"Video"**
# 4. Choose **"1920 x 1080 px"** (standard HD)
# 5. Your blank canvas is ready!
#
# **Or:** Search for "Video Presentation" templates if you want a starting point!
#
# ---
#
# ### **Step 2: Upload Your Visual Assets**
#
# 1. Click **"Uploads"** in the left sidebar
# 2. Click **"Upload files"**
# 3. Upload your images and videos:
#    - All images from `my_ai_story/images/`
#    - All videos from `my_ai_story/videos/` (if you made any)
# 4. Wait for everything to upload
#
# **Pro Tip:** You can drag and drop files directly!
#
# **Note:** You DON'T need to upload voice files - Canva will create them!
#
# ---
#
# ### **Step 3: Add Pages for Each Scene**
#
# Each scene in your storyboard = 1 page in Canva!
#
# 1. Look at how many scenes you have (3-5 scenes)
# 2. Add pages: Click **"+" button** at the bottom
# 3. Create one page per scene
#
# **Example:**
# - Page 1: Title card (optional)
# - Page 2: Scene 1
# - Page 3: Scene 2
# - Page 4: Scene 3
# - Page 5: Ending/credits (optional)
#
# ---
#
# ### **Step 4: Build Scene 1 with Voice!**
#
# Let's do the first scene together step-by-step:
#
# **4a. Add Visual**
# 1. Go to Page 1 (or 2 if you have a title)
# 2. From Uploads, drag your Scene 1 image OR video
# 3. Resize to fill the page
#
# ---
#
# **4b. Add AI Voice (Canva's Text-to-Speech!) 🎤**
#
# This is the cool part - Canva will generate voices for you!
#
# 1. Add a text box: Click **"Text"** in the left sidebar
# 2. Click **"Add a text box"**
# 3. Type or paste your Scene 1 script from your storyboard
#    - Example: "Hello! My name is Robo, and I'm here to help you!"
# 4. Select the text you just typed
# 5. Click **"More"** (three dots) in the text toolbar
# 6. Select **"Text to speech"** or **"Voice over"**
# 7. Choose a voice:
#    - Try different voices by clicking on them
#    - Pick one that fits your character!
#    - Options include: Narrator, Friendly, Young, Energetic, etc.
# 8. Click **"Generate"**
# 9. The AI voice is automatically added to your page!
#
# **🎯 Pro Tip:** You can hide the text box after generating voice (just make it tiny or delete it)
#
# ---
#
# **4c. Set Duration**
# 1. Click on the page thumbnail at bottom
# 2. Click the timer icon
# 3. Set duration based on voice length
#    - Listen to the voice first to see how long it is
#    - Add 1-2 seconds buffer
#    - Example: If voice is 8 seconds → set page to 9-10 seconds
#
# ---
#
# **4d. Preview Scene 1**
# 1. Click the **Play button** (▶️) at top right
# 2. Watch/listen to Scene 1
# 3. Does it work? Great!
# 4. Need to adjust? Change the timing or regenerate voice
#
# ---
#
# ### **Step 5: Build Remaining Scenes**
#
# Repeat Step 4 for each of your scenes!
#
# **For Scene 2:**
# 1. Add Scene 2 visual (image or video)
# 2. Add text with Scene 2 script
# 3. Generate AI voice with text-to-speech
# 4. Set duration to match voice
# 5. Preview
#
# **For Scene 3:**
# 1. Add Scene 3 visual
# 2. Add text with Scene 3 script
# 3. Generate AI voice
# 4. Set duration
# 5. Preview
#
# **Continue for all scenes!**
#
# ---
#
# ### **Step 6: Add Transitions (Optional)**
#
# Make scenes flow smoothly!
#
# 1. Click between two pages (the gap)
# 2. Click **"Transition"**
# 3. Choose a transition style:
#    - **Fade** - Smooth and professional ⭐ Recommended!
#    - **Slide** - Dynamic movement
#    - **Circle wipe** - Fun and creative
#
# **Recommendation:** Use the same transition throughout for consistency!
#
# **Duration:** 0.5 - 1 second is perfect
#
# ---
#
# ### **Step 7: Add Polish ✨ (Optional)**
#
# **Optional Enhancements:**
#
# **A. Title Card (Beginning)**
# 1. Add a page at the start
# 2. Add text with your story title
# 3. Make it look nice with colors/fonts!
# 4. Duration: 3-4 seconds
# 5. Optional: Add voice saying the title!
#
# **B. Text Captions**
# - Add text to show what's being said (like subtitles)
# - Keep them short and readable!
# - Place at bottom of screen
#
# **C. Background Music (Optional)**\n
# \n
# **If you created music in Class 2:**\n
# 1. Click **"Uploads"** in Canva\n
# 2. Upload your music file from `my_ai_story/music/`\n
# 3. Drag it onto your timeline\n
# 4. **IMPORTANT:** Lower volume to 20-30%!\n
# \n
# **OR use Canva's music library:**\n
# 1. Click **"Audio"** in sidebar\n
# 2. Search Canva's music library\n
# 3. Try keywords: "happy", "adventure", "inspiring"\n
# 4. Choose something that fits your mood\n
# 5. **IMPORTANT:** Lower the music volume to 20-30%!\n
# \n
# **D. Visual Effects**
# - Click on an image
# - Click **"Animate"**
# - Choose subtle effects (breathe, pan, zoom)
# - Don't overdo it!
#
# **⚠️ Simple is often better!** Don't add too many effects.
#
# ---
#
# ### **Step 8: Preview Full Story**
#
# Time to watch your complete story!
#
# 1. Click the **Play button** (▶️) at top right
# 2. Watch your ENTIRE story from start to finish
# 3. Check:
#    - □ Does it flow well?
#    - □ Is the audio clear?
#    - □ Can you hear voices over music?
#    - □ Are the timings right?
#    - □ Does it tell your story?
#    - □ Total length is 1-2 minutes?
#
# **Make adjustments as needed!**
#
# ---
#
# ### **Step 9: Export Your Final Story! 🎉**
#
# 1. Click **"Share"** (top right)
# 2. Click **"Download"**
# 3. Select **"MP4 Video"**
# 4. Quality: **Standard** (free) or **High** (with Canva Pro)
# 5. Click **"Download"**
# 6. Wait for it to render (may take 2-5 minutes)
# 7. Save to your computer!
#
# **✅ Save as:** `my_ai_story_final.mp4`
#
# **🎊 CONGRATULATIONS! Your story is complete!**
#
# ---
#
# ## 💡 Alternative Assembly Tools
#
# If Canva isn't working:
#
# **CapCut** (Also has built-in TTS!)
# [👉 Try CapCut](https://www.capcut.com/)
# - Very user-friendly
# - Popular with creators
# - Web and app versions
# - Also has text-to-speech!
#
# **iMovie** (Mac users)
# - Pre-installed on Mac
# - Drag and drop interface
# - Basic TTS available
#
# **Windows Video Editor** (Windows users)
# - Pre-installed on Windows 10/11
# - Simple timeline editing
# - Free!
#
# ---
#
# ## ✅ Assembly Checklist
#
# Before moving to showcase:
#
# - □ All scenes are in the correct order
# - □ Each scene has its visual (image or video)
# - □ Each scene has AI-generated voice narration
# - □ Timing is correct (1-2 minutes total)
# - □ Transitions flow smoothly
# - □ Audio is clear and balanced
# - □ Music volume is not too loud (if added)
# - □ Video is exported and saved
# - □ I can play the final video successfully
# - □ I'm proud of my creation!
#
# ---
#
# ## 🎯 Final Story Details
#
# **Story Title:**
# ```
# [Your story title]
# ```
#
# **Total Duration:**
# ```
# ___ minutes ___ seconds
# ```
#
# **Number of Scenes:**
# ```
# ___ scenes
# ```
#
# **What makes your story special?**
# ```
# [What are you most proud of?]
# ```
#
# ---

# %% [markdown]
# # PART 3: Story Showcase 🎉 {#showcase}
#
# ## 🌟 Time to Share Your Amazing Work!
#
# You've worked hard - now it's time to celebrate!
#
# ---
#
# ## 🎤 Presentation Format
#
# **When it's your turn, you'll:**
#
# ### 1. Introduction (30 seconds)
# - Your name
# - Your story title
# - Quick one-sentence description
#
# **Example:**
# > "Hi, I'm Sarah. My story is called 'Robo's First Day' and it's about a friendly robot who helps kids at school."
#
# ---
#
# ### 2. Play Your Story! (1-2 minutes)
# - Show your final video
# - Everyone watches and listens
# - Enjoy the moment!
#
# ---
#
# ### 3. Behind the Scenes (1 minute)
#
# Share briefly:
# - **Favorite part to create:** What did you enjoy most?
# - **Biggest challenge:** What was hardest?
# - **Coolest AI moment:** What surprised or amazed you?
#
# ---
#
# ### 4. Q&A (30 seconds)
# - Classmates can ask questions
# - Share tips or techniques
# - Celebrate together!
#
# ---
#
# ## 📝 Prepare Your Presentation
#
# **My Story Title:**
# ```
# [Your title]
# ```
#
# **One-sentence description:**
# ```
# [What's your story about?]
# ```
#
# **My favorite part to create was:**
# ```
# [What did you enjoy most - planning, images, videos, or assembly?]
# ```
#
# **The biggest challenge was:**
# ```
# [What was hardest and how did you solve it?]
# ```
#
# **The coolest AI moment was:**
# ```
# [What surprised or amazed you about AI?]
# ```
#
# **If I could add one more thing, it would be:**
# ```
# [What would you do next time?]
# ```
#
# ---
#
# ## 👥 Being a Great Audience
#
# **While watching others:**
#
# **DO:**
# - 👀 Give your full attention
# - 👏 Applaud every presentation
# - 😊 Be supportive and encouraging
# - 💬 Ask thoughtful, kind questions
# - 🌟 Find something you liked about each story
#
# **DON'T:**
# - Compare stories (everyone's is unique!)
# - Talk during presentations
# - Focus on technical issues
# - Forget that everyone worked hard
#
# ---
#
# ## 🏆 Celebrating Everyone
#
# **Remember:**
# - Every story is different and special
# - Every person learned and grew
# - There's no "best" - only unique creations
# - You all used AI to bring YOUR vision to life!
#
# **That's incredible!** 🎉
#
# ---
#
# ## 📸 After the Showcase
#
# **Things to do:**
# - □ Get feedback from classmates
# - □ Write down compliments you received
# - □ Think about what you learned from others
# - □ Save your final video somewhere safe
# - □ Share with family (with permission)!
#
# **Feedback I received:**
# ```
# [What did people say they liked about your story?]
# ```
#
# **Inspiration from others:**
# ```
# [What cool ideas did you see in other stories?]
# ```
#
# ---

# %% [markdown]
# # PART 4: Reflection & Celebration 🎓 {#reflection}
#
# ## 🌟 You Did It!
#
# **Congratulations on completing the Explorer Level AI Workshop!**
#
# Take a moment to think about your entire journey...
#
# ---
#
# ## 🧠 Final Reflection Questions
#
# ### **1. What did you learn about AI and creativity from this workshop?**
# ```
# [Your thoughts - how does AI help creativity? What can it do?]
# ```
#
# ---
#
# ### **2. What was your favorite part of the entire workshop?**
# ```
# [Class 1, 2, or 3? Which activity or tool?]
# ```
#
# ---
#
# ### **3. What was the biggest challenge and how did you overcome it?**
# ```
# [What was hard? What did you do to solve it?]
# ```
#
# ---
#
# ### **4. How did AI tools help you be more creative?**
# ```
# [Did AI help you do things you couldn't do before?]
# ```
#
# ---
#
# ### **5. What would you create next with AI?**
# ```
# [Future ideas - what else could you make?]
# ```
#
# ---
#
# ### **6. What advice would you give to someone starting this workshop?**
# ```
# [Wisdom for future students!]
# ```
#
# ---
#
# ### **7. How do you feel about AI now compared to before the workshop?**
# ```
# [Did your perspective change? Are you excited? Curious?]
# ```
#
# ---
#
# ### **8. What surprised you most about AI?**
# ```
# [What was unexpected or amazing?]
# ```
#
# ---
#
# ## 🎓 Workshop Completion Checklist
#
# **Check off everything you accomplished:**
#
# ### **Class 1: Discover AI Around You**
# - □ Learned what AI is and how it works
# - □ Found AI in daily life
# - □ Used ChatGPT for conversations
# - □ Explored AI translation
# - □ Learned about deepfakes
# - □ Discussed AI ethics and "AI for Good"
#
# ### **Class 2: Plan Your Story & Create with AI**
# - □ Planned my complete story
# - □ Created detailed storyboard
# - □ Learned to write AI prompts
# - □ Generated AI images for my story
# - □ Organized files properly
#
# ### **Class 3: Animate, Voice & Assemble**
# - □ Animated images into videos (optional)
# - □ Used Canva's AI text-to-speech for voices
# - □ Assembled complete story in Canva
# - □ Created 1-2 minute final video
# - □ Presented to class
# - □ Reflected on learning
#
# ---
#
# ## 🏆 Skills You've Gained
#
# **You now know how to:**
# - 🧠 Understand what AI is and how it works
# - 💬 Use ChatGPT for assistance and ideas
# - ✍️ Write effective AI prompts
# - 🎨 Create AI-generated images
# - 🎬 Animate images into videos (optional)
# - 🎤 Generate AI voices from text
# - 🎥 Assemble multimedia projects
# - 📖 Tell stories with AI tools
# - 🤔 Think critically about AI ethics
# - 🎤 Present your work confidently
#
# **That's AMAZING!** 🌟
#
# ---
#
# ## 🚀 What's Next?
#
# ### **Keep Exploring:**
# - Try the Bonus Modules in the workshop
# - Create more AI stories at home
# - Experiment with new AI tools
# - Share your work with friends and family
#
# ### **Ready for More?**
# You're ready for the **Beginner Level** workshop!
# - Learn basic coding with AI
# - Build interactive AI projects
# - Understand how AI works "under the hood"
#
# ### **Join the AI Community:**
# - Share your projects online (with parent permission)
# - Learn from other young AI creators
# - Keep learning and growing!
#
# ---
#
# ## 💫 Final Thoughts
#
# **Remember these important lessons:**
#
# ✨ **AI is a tool, not magic**
# - You learned how to use AI tools effectively
# - Tools need good instructions (prompts) from YOU
#
# 🎨 **Your creativity matters most**
# - AI can't replace your imagination
# - The best part of your story was YOUR idea!
#
# 🤝 **AI should help people**
# - Use AI responsibly and ethically
# - Think about how AI can make the world better
#
# 📚 **Keep learning and creating**
# - AI technology is always improving
# - Stay curious and keep exploring
# - There's so much more to discover!
#
# ---
#
# ## 🎉 CONGRATULATIONS!
#
# **You've completed the Explorer Level AI Workshop!**
#
# **You are now:**
# - ✅ An AI Explorer
# - ✅ A creative storyteller
# - ✅ A prompt engineer
# - ✅ A multimedia creator
# - ✅ Ready for more AI adventures!
#
# **Keep creating amazing things!** 🚀✨
#
# ---
#
# ## 📦 Save Your Work!
#
# **Create a portfolio of your work:**
# - □ Save your final video
# - □ Keep your best images
# - □ Save your storyboard
# - □ Write down your favorite prompts
# - □ Take screenshots of your process
#
# **This is the beginning of your AI journey!** 🌟
#
# ---
#
# > 💡 **Tip for Parents/Teachers:**
# > - Celebrate each student's unique achievement!
# > - Consider creating certificates of completion
# > - Share student work with families (with permission)
# > - Create a class showcase video or gallery
# > - Encourage continued exploration with Bonus Modules
# > - Connect students to future learning opportunities!
#
# ---
#
# **Thank you for exploring AI with us!**
#
# **Keep learning, keep creating, and most importantly — have fun!** 🎊
#
# *Every expert was once a beginner. Keep going!* ⭐

# %% [markdown]
# # ⭐ BONUS: Advanced Options {#bonus}
#
# **These are OPTIONAL activities for students who want to explore more!**
#
# If you finish early or want to enhance your story, try these!
#
# ---
#
# ## 🎤 BONUS Option 1: Professional AI Voice (ElevenLabs)
#
# **For students who want ULTRA-realistic voices!**
#
# Canva's text-to-speech is great, but if you want even MORE natural-sounding voices, try ElevenLabs!
#
# ### When to use this:
# - ✅ You want the highest quality voices
# - ✅ You have extra time
# - ✅ You want more voice variety
# - ✅ You're creating a longer or more complex story
#
# ---
#
# ### 🛠️ Tool: ElevenLabs
#
# [👉 Open ElevenLabs](https://elevenlabs.io/app/speech-synthesis)
#
# **Why ElevenLabs?**
# - ✅ Most natural-sounding AI voices
# - ✅ 100+ voice options
# - ✅ More emotional range
# - ✅ Better for professional storytelling
# - ✅ Free tier available
#
# ---
#
# ### How to Use:
#
# **Step 1: Set Up Account**
# 1. Go to [ElevenLabs](https://elevenlabs.io)
# 2. Sign up or log in
# 3. Navigate to "Speech Synthesis"
#
# **Step 2: Choose a Voice**
# 1. Click on the voice dropdown
# 2. Preview different voices
# 3. Choose one that fits your character!
#
# **Step 3: Generate Voice**
# 1. Paste your script from storyboard
# 2. Click "Generate"
# 3. Download the MP3 file
# 4. Upload to Canva and use instead of text-to-speech
#
# **Pro Tip:** Use different voices for different characters!
#
# ---
#
# ### When to use this:
# - ✅ You want custom music that matches your story's mood
# - ✅ You have extra time
# - ✅ You want to learn about AI music
# - ✅ You want your story to be extra special
#
# ---
#
# ### 🎹 Recommended AI Music Tools:
#
# #### **Option A: Suno AI** (Best for beginners!)
# [👉 Try Suno](https://suno.com)
#
# **How it works:**
# 1. Describe the mood you want
#    - Example: "Cheerful, upbeat music for a kids story"
#    - Example: "Gentle, calm background music"
# 2. Suno creates a 30-second to 2-minute track
# 3. Download and add to Canva!
#
# **Free Tier:** Limited songs per day
#
# ---
#
# #### **Option B: Soundraw**
# [👉 Try Soundraw](https://soundraw.io)
#
# **How it works:**
# 1. Choose:
#    - Mood (Happy, Epic, Calm, etc.)
#    - Genre (Pop, Cinematic, Electronic, etc.)
#    - Length (match your video length!)
# 2. AI generates music
# 3. Download and use!
#
# **Free Tier:** Can generate and preview, may need subscription to download
#
# ---
#
# #### **Option C: AIVA**
# [👉 Try AIVA](https://www.aiva.ai)
#
# **How it works:**
# 1. Choose emotional tone and style
# 2. AIVA composes original music
# 3. Download and add to your video
#
# **Free Tier:** Personal use with AIVA credit
#
# ---
#
# ### 🎵 AI Music Creation Workflow:
#
# **Step 1: Plan Your Music**
# Think about your story:
# - What mood? (happy, sad, exciting, calm)
# - What energy? (high energy, relaxed, building up)
# - How long? (match your video length!)
#
# **Step 2: Generate Music**
# Use one of the tools above to create your track
#
# **Step 3: Add to Canva**
# 1. Download your AI-generated music
# 2. In Canva, click "Uploads"
# 3. Upload your music file
# 4. Drag it onto your video timeline
# 5. **IMPORTANT:** Lower volume to 20-30%!
#
# ---
#
# ### 💡 Music Pro Tips:
#
# **DO:**
# - ✅ Match music mood to story mood
# - ✅ Keep music volume LOW (background only!)
# - ✅ Make sure music doesn't distract from voices
# - ✅ Consider having different music for different scenes
#
# **DON'T:**
# - ❌ Make music too loud (voices should be clear!)
# - ❌ Use multiple competing music tracks
# - ❌ Forget to check copyright/licensing
# - ❌ Stress about finding "perfect" music
#
# ---
#
# ## 🎬 Using AI Music in Your Story:
#
# **Example Story Plan:**
# - **Scene 1-2:** Cheerful, upbeat music (robot's introduction)
# - **Scene 3:** Gentle, calm music (learning moment)
# - **Scene 4-5:** Happy, triumphant music (success!)
#
# **OR keep it simple:**
# - One consistent background track throughout
# - Let your voices and story do the talking!
#
# ---
#
# ## ✅ Bonus Activities Checklist:
#
# **If you try these, check them off:**
#
# **Advanced Voice:**
# - □ Created ElevenLabs account
# - □ Explored different voice options
# - □ Generated professional voices
# - □ Added to my story
#
# **AI Music:**
# - □ Explored AI music generation tools
# - □ Generated custom background music
# - □ Added music to my Canva project
# - □ Balanced music volume with voices
#
# ---
#
# ## 🌟 Remember:
#
# **These are OPTIONAL!**
# - Your story is complete WITHOUT these
# - Only do these if you have time and interest
# - The core workflow (Canva TTS + built-in music) works great!
# - These are for students who want to go deeper
#
# **What you learn:**
# - Understanding that AI tools come in different quality levels
# - Professional creators use specialized tools
# - How to enhance your work with advanced AI
# - The AI ecosystem is vast and always growing!
#
# ---
#
# **Happy creating!** 🎨🎵✨
