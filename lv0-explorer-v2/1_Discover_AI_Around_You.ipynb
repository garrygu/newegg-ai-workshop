# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/garrygu/newegg-ai-workshop/blob/main/lv0-explorer-v2/1_Discover_AI_Around_You.ipynb)

# %% [markdown]
# # 🌍 Discover AI Around You
#
# **Welcome to Your AI Adventure!** 🚀
#
# This is your first step into the amazing world of Artificial Intelligence. No coding needed - just curiosity and creativity!
#
# > 🎯 **Your Final Goal:** By the end of this workshop, you'll create your own **multimedia AI story** — combining AI-generated images, videos, voices, and your creativity into an amazing project! Keep this in mind as you explore today.
#
# ---
#
# ## ⏱️ Session Overview
# **Total Time:** 2 hours (120 minutes)
# **Break Time:** 10-15 minutes
# **Active Learning:** ~105-110 minutes
#
# ### 📅 Suggested Schedule:
# - **00:00-00:10** - Welcome & Introduction (10 min)
# - **00:10-00:25** - What is AI? & Warm-Up Activity (15 min)
# - **00:25-00:45** - AI in Daily Life Exploration (20 min)
# - **00:45-01:15** - Hands-On ChatGPT Session (30 min)
# - **01:15-01:30** - BREAK ☕ (15 min)
# - **01:30-01:50** - AI Translation & Deepfake Detection (20 min)
# - **01:50-02:05** - AI for Good Challenge (15 min)
# - **02:05-02:20** - Wrap-up & Reflection (15 min)
#
# ---
#
# ## 📋 Table of Contents
# 1. [What is AI?](#what-is-ai)
# 2. [Warm-Up Activity](#warm-up)
# 3. [AI in Daily Life](#everyday-ai)
# 4. [Hands-On: ChatGPT](#try-it-yourself)
# 5. [AI Translation & Language](#translation)
# 6. [Spot the Fake: AI Deepfakes](#deepfakes)
# 7. [AI for Good Challenge](#ai-for-good)
# 8. [Challenges & Activities](#challenges)
# 9. [Reflection](#reflection)
#
# ---

# %% [markdown]
# ## 🎯 Goal {#what-is-ai}
# Learn what AI is and how it helps in daily life! Explore fun examples and see AI in action.
#
# **By the end of this notebook, you will:**
# - ✨ Know what AI means
# - 🌟 Recognize AI in everyday life
# - 💬 Chat with an AI assistant
# - 🤔 Think about how AI helps people
#
# ---
#
# ## 🤖 What is AI (Artificial Intelligence)?
#
# **AI** stands for **Artificial Intelligence** — it's like giving computers the ability to **think** and **learn**!
#
# Think of AI as:
# - 🧠 A smart helper that learns from experience
# - 🤖 A robot brain that can recognize patterns
# - 🎨 A creative assistant that can make art, stories, and more
#
# > 🧠 **Tech Talk:** The core way AI learns is called **Machine Learning**. Instead of being programmed with every rule, AI learns from data — lots and lots of examples! It's like teaching someone to recognize cats by showing them thousands of cat photos, rather than describing what a cat looks like. The more data the AI sees, the better it gets at recognizing patterns and making decisions. This is why AI improves over time!
#
# > 💡 **Fun Fact:** AI can recognize faces in photos, understand what you say, recommend videos you might like, and even help write stories!
#
# ---
#
# ## 💡 Warm-Up: "AI or Human?" {#warm-up}
#
# **Activity Time!** 🎮
#
# Your instructor will show you some examples. Look carefully — can you guess which ones were created by AI?
#
# ### Examples to Look For:
# - 📝 Stories or poems
# - 🎨 Pictures or artwork
# - 🎵 Music or songs
# - 💬 Conversations or chats
#
# **Write your guesses below:**
# - Example 1: AI or Human? __________
# - Example 2: AI or Human? __________
# - Example 3: AI or Human? __________
#
# > 🤔 **Think:** Was it easy or hard to tell? What made you decide?
#
# ---
#
# ## 🔍 Everyday AI Examples {#everyday-ai}
#
# AI is **everywhere** around you! Look for these examples:
#
# ### 🏠 At Home
# - 📱 **Smartphones** — Face recognition, voice assistants (Siri, Alexa)
#
#   > 🧠 **Tech Talk:** Face recognition uses something called a **Neural Network**. The AI sees your photo as a grid of numbers (each pixel is a number representing color and brightness). It uses layers of math to find patterns — like detecting edges, then shapes, then features like eyes, nose, and mouth — to identify a face. It's like the AI is looking through multiple filters, each one finding more complex patterns!
#
# - 📺 **Streaming Services** — Netflix, YouTube recommendations
# - 🎮 **Gaming** — Smart characters that play against you
#
#   > 🧠 **Tech Talk:** Game AI often uses a **Decision Tree** to choose its next move. Think of it like a flowchart: Is the player visible? → Yes → Is the player close? → Yes → Attack! → No → Move closer. Each question leads to a decision, just like choosing your path in a maze. This helps game characters react intelligently to what's happening around them!
#
# ### 🏫 At School
# - 📚 **Learning Apps** — Personalized study plans
# - ✍️ **Writing Tools** — Grammar and spell checkers
# - 🔍 **Search Engines** — Google, Bing finding answers
#
# ### 🚗 In the World
# - 🗺️ **Navigation** — GPS apps like Google Maps
# - 📸 **Photo Apps** — Snapchat filters, Instagram effects
# - 🛒 **Online Shopping** — Product recommendations
#
# ### 🎨 Creative AI
# - **ChatGPT** — Writing stories and answering questions
# - **DALL·E** — Creating images from text
# - **AI Music** — Composing songs and beats
#
# ---
#
# ## 💬 Try It Yourself: ChatGPT {#try-it-yourself}
#
# **Let's Chat with AI!** 🗣️
#
# > 🧠 **Tech Talk:** ChatGPT is powered by a **Large Language Model (LLM)**. Here's the simple version: The AI has been trained on a massive amount of text from books, websites, and conversations. When you type a message, it predicts the next most likely word based on all that training, then the next word, and so on — building a response one word at a time. It's like having a super-smart friend who has read almost everything on the internet and can continue any conversation!
#
# 1. Click the link below to open ChatGPT
# 2. You might need to create a free account (ask your instructor for help)
# 3. Type a message in the chat box and see what happens!
#
# [👉 Open ChatGPT](https://chat.openai.com/)
#
# ### 📝 First Conversation Ideas:
# Try asking ChatGPT one of these questions:
# - "Tell me a fun fact about space"
# - "What's the best flavor of ice cream?"
# - "Help me plan my perfect weekend"
# - "Write a short poem about robots"
#
# **Write your favorite ChatGPT response here:**
# ```
# [Your response goes here!]
# ```
#
# ---
#
# ## 💪 Challenges & Activities {#challenges}
#
# ### Challenge 1: Dream Vacation Planner ✈️
# Ask ChatGPT to design a 1-day plan for your dream vacation!
#
# **Prompt to try:**
# > "Plan a perfect day for me at [your dream destination]. Include activities, food, and fun things to do!"
#
# **Describe your favorite part of the plan:**
# ```
# [Write about your favorite part here]
# ```
#
# ---
#
# ### Challenge 2: AI Detective 🔍
# Explore your phone or tablet and find **3 examples of AI**!
#
# **List what you found:**
# 1. **Example 1:** _______________________
#    - Where: _______________________
#    - How it uses AI: _______________________
#
# 2. **Example 2:** _______________________
#    - Where: _______________________
#    - How it uses AI: _______________________
#
# 3. **Example 3:** _______________________
#    - Where: _______________________
#    - How it uses AI: _______________________
#
# ---
#
# ### Challenge 3: Creative Writing with AI ✨
# Ask ChatGPT to help you write:
# - A short story about a robot friend
# - A poem about your favorite hobby
# - A funny joke
# - An adventure story
#
# **Share what you created:**
# ```
# [Paste your favorite creation here]
# ```
#
# ---
#
# ### Challenge 4: AI Comparison 🆚
# Try this experiment:
# 1. Ask ChatGPT to write a story about a magical forest
# 2. Try writing your own story about a magical forest
# 3. Compare them — what's similar? What's different?
#
# **Your observations:**
# ```
# Similarities:
# -
# -
#
# Differences:
# -
# -
# ```
#
# ---
#
# ## 🧠 Reflection {#reflection}
#
# Take a moment to think about what you've learned!
#
# ### Questions to Answer:
#
# 1. **In your own words, what is AI?**
#    ```
#    [Your answer here]
#    ```
#
# 2. **Where do you think AI helps people the most today?**
#    ```
#    [Your thoughts here]
#    ```
#
# 3. **Name one new thing you discovered about AI today:**
#    ```
#    [Share your discovery]
#    ```
#
# 4. **How do you feel about AI after this lesson?**
#    - 😊 Excited
#    - 🤔 Curious
#    - 🎨 Creative
#    - 🌟 Amazed
#    - [Other: _______________]
#
# 5. **What would you like to learn about AI next?**
#    ```
#    [Your ideas here]
#    ```
#
# ---
#
# ---
#
# ## 🌍 AI Translation & Language Understanding {#translation}
#
# **Discover how AI understands different languages!** 🗣️🌐
#
# AI doesn't just speak one language — it can translate and understand many! Let's explore how AI works with languages.
#
# ### Step 1: Try AI Translation
#
# [👉 Try DeepL Translator](https://www.deepl.com/translator)
#
# **Activity: Translation Test**
# 1. Write 2-3 sentences about AI in English
# 2. Translate it to another language (Spanish, French, Japanese, etc.)
# 3. Translate it back to English — did anything change?
#
# **My Original Text:**
# ```
# [Write your sentences here]
# ```
#
# **Translation Experiment:**
# - **Language 1:** ___________ (What changed?)
# - **Language 2:** ___________ (What changed?)
#
# **Observations:**
# ```
# What stayed the same?
# -
#
# What changed?
# -
#
# Was the meaning preserved?
# -
# ```
#
# ---
#
# ### Step 2: Context and Ambiguity Challenge
#
# **Why is translation so hard?** 🤔
#
# Sometimes, sentences can mean different things depending on context! This is one of the biggest challenges in **Natural Language Processing (NLP)** — the field of AI that works with human language.
#
# **Try this ambiguous sentence:**
#
# > "The man saw the dog with the telescope."
#
# **Think about it:**
# - Who had the telescope?
#   - The man? (The man used a telescope to see the dog)
#   - The dog? (The dog had a telescope, and the man saw it)
#
# **How does AI know which meaning is correct?**
#
# The AI has to use **context** — clues from surrounding words, sentences, or the situation — to figure out the most likely meaning. It's like solving a puzzle!
#
# **Activity: Test the Ambiguity**
#
# 1. Try translating this sentence to another language using [DeepL Translator](https://www.deepl.com/translator)
# 2. Translate it back to English
# 3. Did the AI pick one meaning? Which one?
#
# **My Translation Result:**
# ```
# [What did the AI choose?]
# ```
#
# **Now try adding context:**
#
# > "The astronomer looked through his telescope. The man saw the dog with the telescope."
#
# **What changed?** Now it's clearer that the man had the telescope!
#
# **Your observations:**
# ```
# How did adding context help?
# -
#
# Why is this a challenge for AI?
# -
# ```
#
# > 🧠 **Tech Talk:** This is a core challenge in **Natural Language Processing (NLP)**. Human language is full of ambiguity — words can have multiple meanings, sentences can be interpreted different ways, and context matters a lot. AI translation systems use context clues, patterns from training data, and statistical analysis to guess the most likely meaning, but sometimes they get it wrong, just like humans do!
#
# ---
#
# ### Step 3: Cultural Understanding
#
# **Discussion Questions:**
# 1. **How well did the meaning stay the same?**
#    ```
#    [Your thoughts]
#    ```
#
# 2. **What challenges might AI face in understanding culture?**
#    ```
#    [Think about jokes, idioms, expressions]
#    ```
#
# 3. **Can AI understand feelings and emotions in different languages?**
#    ```
#    [Your opinion]
#    ```
#
# > 💡 **Fun Fact:** Some words don't have direct translations! For example, "saudade" in Portuguese means a deep emotional state of longing, but there's no exact English word for it.
#
# ---
#
# ## 🕵️ Spot the Fake: AI Deepfakes {#deepfakes}
#
# **Learn how AI can create fake images and why that matters!** 🎭✨
#
# **Deepfakes** are AI-generated images or videos that look real but are completely fake. Let's learn to spot them!
#
# > 🧠 **Tech Talk:** Many deepfakes are created using **Generative Adversarial Networks (GANs)**. Think of it like a game between two AIs: One AI (the **Generator**) tries to create a fake image that looks real, while another AI (the **Discriminator**) tries to spot the fake. They train each other — when the Generator gets better at making fakes, the Discriminator has to get better at spotting them, and vice versa! This competition makes both AIs improve, which is why deepfakes have become so realistic. It's like two players practicing against each other and both getting stronger!
#
# ### Activity: Which Face Is Real?
#
# [👉 Try "Which Face Is Real?" Game](https://www.whichfaceisreal.com/)
#
# **How to Play:**
# 1. Visit the website — look at the two faces shown
# 2. Guess: which one is real, which one is AI-generated?
# 3. Click to reveal the answer
# 4. Try 5-10 examples and see how many you get right!
#
# **Your Results:**
# ```
# Correct guesses: ___ out of 10
# ```
#
# ---
#
# ### Discussion: Why Is This Important?
#
# **Think about these questions:**
#
# 1. **Why is it hard to tell the difference?**
#    ```
#    [Your observations]
#    ```
#
# 2. **How might fake images/videos be used for good?**
#    - Entertainment (movies, games)
#    - Education (historical recreations)
#    - Art and creativity
#    - [Your ideas:]
#
# 3. **How might fake images/videos be used for bad?**
#    - Spreading misinformation
#    - Fake news
#    - Impersonating people
#    - [Your concerns:]
#
# 4. **What rules or safeguards should exist?**
#    ```
#    [Your suggestions]
#    ```
#
# ---
#
# ### Challenge: Create Your Own Deepfake Awareness Poster
#
# Use Canva or draw on paper to create a poster that teaches others about deepfakes!
#
# **Poster Elements:**
# - [ ] What are deepfakes?
# - [ ] Why should we be careful?
# - [ ] How to spot fake images?
# - [ ] A catchy slogan!
#
# **My Poster Idea:**
# ```
# [Describe or sketch your poster idea]
# ```
#
# ---
#
# ## 💡 AI for Good Challenge {#ai-for-good}
#
# **Think about how AI can make the world better!** 🌟🌍
#
# ### Brainstorming Session
#
# **Step 1: Generate Ideas with ChatGPT**
#
# Ask ChatGPT: **"Give me 5 creative ideas for how AI can help the environment."**
#
# [👉 Open ChatGPT](https://chat.openai.com/?model=gpt-4o)
#
# **AI's Ideas:**
# ```
# 1.
# 2.
# 3.
# 4.
# 5.
# ```
#
# ---
#
# ### Step 2: Choose Your Favorite
#
# **Pick the idea you like most and explain why:**
#
# **My Favorite Idea:**
# ```
# [Which one and why?]
# ```
#
# **How would this help?**
# ```
# [Explain the impact]
# ```
#
# ---
#
# ### Step 3: Design Your "AI for Good" Project
#
# Create a simple plan for an AI project that helps solve a problem!
#
# **Project Template:**
#
# **Problem:** What problem does your project solve?
# ```
# [Describe a real-world problem]
# ```
#
# **Solution:** How can AI help?
# ```
# [Your AI-powered solution]
# ```
#
# **Impact:** Who would benefit?
# ```
# [Who would be helped by this?]
# ```
#
# **Project Name:** ___________
#
# ---
#
# ### Team Challenge: AI for Good Pitch
#
# **Work in groups of 3-4:**
#
# 1. **Share your AI for Good ideas** (5 minutes)
# 2. **Choose one idea as a team** (5 minutes)
# 3. **Create a 1-minute pitch** explaining:
#    - The problem
#    - How AI solves it
#    - Who it helps
#    - Why it matters
# 4. **Present to the class!** (1 minute per team)
#
# **Team Members:**
# - ___________
# - ___________
# - ___________
# - ___________
#
# **Our Team's Idea:**
# ```
# [Your team's chosen project]
# ```
#
# **Our Pitch:**
# ```
# [Write your 1-minute pitch here]
# ```
#
# ---
#
# ## 💪 Additional Challenges & Activities {#challenges}
#
# ### Challenge 5: AI Ethics Scenarios 🤔
#
# **Read each scenario and discuss with your group:**
#
# **Scenario 1: AI in School**
# A school uses AI to grade all homework automatically. Is this good or bad?
#
# **Your Thoughts:**
# ```
# Pros:
# -
#
# Cons:
# -
#
# Your Opinion:
# ```
#
# ---
#
# **Scenario 2: AI Doctors**
# AI can diagnose diseases from medical images. Should doctors always trust AI?
#
# **Your Thoughts:**
# ```
# Pros:
# -
#
# Cons:
# -
#
# Your Opinion:
# ```
#
# ---
#
# **Scenario 3: AI and Jobs**
# Some jobs are being done by AI now. What should happen to the people who used to do those jobs?
#
# **Your Thoughts:**
# ```
# [Discuss this complex topic]
# ```
#
# ---
#
# ### Challenge 6: Future AI Predictions 🔮
#
# **Imagine AI in 10 years. What do you think will be possible?**
#
# **My Predictions:**
# ```
# 1.
# 2.
# 3.
# ```
#
# **Share with the class and compare ideas!**
#
# ---
#
# ## 🧠 Reflection {#reflection}
#
# Take a moment to think about what you've learned!
#
# ### Questions to Answer:
#
# 1. **In your own words, what is AI?**
#    ```
#    [Your answer here]
#    ```
#
# 2. **Where do you think AI helps people the most today?**
#    ```
#    [Your thoughts here]
#    ```
#
# 3. **What was the most surprising thing you learned about AI today?**
#    ```
#    [Share your discovery]
#    ```
#
# 4. **What concerns do you have about AI?**
#    ```
#    [Your concerns]
#    ```
#
# 5. **How do you feel about AI after this lesson?**
#    - 😊 Excited
#    - 🤔 Curious
#    - 🎨 Creative
#    - 🌟 Amazed
#    - 😟 Worried
#    - 💭 Thoughtful
#    - [Other: _______________]
#
# 6. **What would you like to learn about AI next?**
#    ```
#    [Your ideas here]
#    ```
#
# 7. **What responsibility do we have when using AI?**
#    ```
#    [Your thoughts on ethics and responsibility]
#    ```
#
# ---
#
# ## 🎉 Congratulations!
#
# You've completed **Session 1: Discover AI Around You**!
#
# **You've learned about:**
# - ✨ What AI is and how it works
# - 🌍 AI in everyday life
# - 💬 ChatGPT and AI assistants
# - 🌐 AI translation and language
# - 🕵️ Deepfakes and AI authenticity
# - 💡 AI for Good projects
# - 🤔 AI ethics and responsibility
#
# **Next Up:** 🎨 [Create with AI Images](./2_Create_with_AI_Images.ipynb) — Learn to make pictures with just words!
#
# **Remember:** Every AI expert started by exploring just like you! Keep asking questions and trying new things! 🌟
#
# ---
#
# > 💡 **Tip for Parents/Teachers:**
# > - Allow time for discussions - ethical questions need time to explore
# > - Encourage students to share different perspectives
# > - Use the break time for informal conversations about AI
# > - Save time at the end for sharing and reflection
# > - Create a safe space where all questions and concerns are welcome!
