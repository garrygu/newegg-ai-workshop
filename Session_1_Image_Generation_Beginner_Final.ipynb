# %% [markdown]
# # 🎨 Session 1 – Create with AI: Image Generation
#
# Today, you’ll experience how AI can **create images from words** — a process called *text-to-image generation*. You’ll start by seeing how AI interprets simple prompts and then design your own creative images.

# %% [markdown]
# ### What You’ll Learn
# - How AI turns text into images
# - How to write creative prompts
# - How to save your generated images for later use (like your AI game!)
# ---

# %% [markdown]
# ### 🎯 The Big Picture
# AI image generation is like having a super-smart artist that can paint anything you describe! Here's how it works:
#
# ### 📝 1. Text Understanding
# - You write a **prompt** (description) like "a cute cat wearing a hat"
# - The AI reads your words and understands what you want
# - It breaks down concepts: "cat" + "cute" + "hat" + "wearing"
#
# ### 🧮 2. Pattern Learning
# - The AI was trained on **millions of images** with descriptions
# - It learned patterns like: "cats have whiskers", "hats go on heads", "cute means big eyes"
# - It's like studying thousands of art books to understand style and composition
#
# ### 🎨 3. Image Creation Process
# ```
# Your Text → AI Brain → Mathematical Magic → Beautiful Image
# ```
#
# ### 📊 Visual Overview: The AI Image Generation Process
#
# Here's a simple diagram showing how your text becomes an image:
#
# ```
# ┌─────────────────┐    ┌─────────────────┐    ┌─────────────────┐
# │   Your Prompt   │───▶│   AI Brain      │───▶│  Generated      │
# │ "cute cat hat"  │    │ (Processing)    │    │    Image        │
# └─────────────────┘    └─────────────────┘    └─────────────────┘
#          │                       │                       │
#          ▼                       ▼                       ▼
#    📝 Text Input            🧮 Math Magic            🎨 Visual Output
# ```
#
# **Step-by-Step Breakdown:**
# 1. **Input**: You type "a cute cat wearing a hat"
# 2. **Understanding**: AI breaks it down into concepts
# 3. **Processing**: AI uses learned patterns to create the image
# 4. **Output**: You get a beautiful, unique image!
#
# **Real Example:**
# - Input: "a robot playing guitar in space"
# - AI thinks: robot + guitar + space + playing
# - Output: A cool sci-fi image of a robot musician! 🤖🎸🚀
#
# ### 🌟 Why It's Amazing
# - **No drawing skills needed** - just describe what you want!
# - **Infinite creativity** - try any combination of ideas
# - **Fast results** - from idea to image in seconds
# - **Learning tool** - helps you understand how AI "thinks"
#
# ### 💡 Think of it as...
# Having a magical paintbrush that understands English and can paint anything you describe! 🪄
#
# **The Technical Magic:**
# - **Text Encoder**: Converts your words into numbers the AI understands
# - **Diffusion Model**: Starts with random noise and gradually "paints" your image
# - **Image Decoder**: Converts the AI's internal representation into pixels
#
# ---

# %% [markdown]
# ## 👀 Step 1: See What AI Can Do
# Before setting up the tools, let’s look at an example of an AI-generated image. Run the cell below!

# %%
from PIL import Image
import requests
from io import BytesIO

url = 'https://huggingface.co/datasets/hf-internal-testing/diffusers-images/resolve/main/text2img_samples/dog_cat.png'
Image.open(BytesIO(requests.get(url).content))

# %% [markdown]
# <details>
# <summary>📝 What does this code do? (Click to Expand)</summary>
#
# Let's break down each line of code:
#
# ```python
# from PIL import Image
# ```
# - **PIL** = Python Imaging Library (now called Pillow)
# - **Image** = A class for working with images
# - This lets us open, display, and manipulate images
#
# ```python
# import requests
# ```
# - **requests** = A library for making HTTP requests
# - This lets us download files from the internet
#
# ```python
# from io import BytesIO
# ```
# - **BytesIO** = A way to treat bytes data as a file
# - This helps us work with image data downloaded from the web
#
# ```python
# url = 'https://huggingface.co/datasets/hf-internal-testing/diffusers-images/resolve/main/text2img_samples/dog_cat.png'
# ```
# - **url** = The web address where the example image is stored
# - This is a sample AI-generated image from Hugging Face
#
# ```python
# Image.open(BytesIO(requests.get(url).content))
# ```
# - **requests.get(url)** = Downloads the image from the web
# - **.content** = Gets the raw image data (bytes)
# - **BytesIO(...)** = Converts bytes to a file-like object
# - **Image.open(...)** = Opens the image and displays it
#
# **In simple terms:** We're downloading a sample AI-generated image from the internet and showing it to you! 🖼️
#
# </details>

# %% [markdown]
# ---
#
# ## ⚙️ Step 2: Setup the Tools
# We’ll install a few AI libraries that help Python create images from text. This step might take a few minutes, but don’t worry — it’s automatic.

# %%
# !pip install --quiet diffusers transformers accelerate safetensors

# %% [markdown]
# <details>
# <summary>📦 What does this pip install command do and where do these libraries come from?  (Click to expand)</summary>
#
# Let's break down this command:
#
# ```bash
# !pip install --quiet diffusers transformers accelerate safetensors
# ```
#
# - **`!`** = Tells Jupyter to run this as a system command (not Python code)
# - **`pip`** = Python's package installer (like an app store for Python libraries)
# - **`install`** = Download and set up the libraries
# - **`--quiet`** = Install without showing lots of progress messages
# - **`diffusers transformers accelerate safetensors`** = The four libraries we're installing
#
# #### 🎯 **What Each Library Does:**
#
# **🎨 `diffusers`**
# - **Purpose**: The main library for AI image generation
# - **What it does**: Provides Stable Diffusion and other image generation models
# - **GitHub**: [github.com/huggingface/diffusers](https://github.com/huggingface/diffusers)
# - **Think of it as**: The "paintbrush" for our AI artist
# - **Used by**: Major tech companies worldwide
#
# **🧠 `transformers`**
# - **Purpose**: Helps AI understand and process text
# - **What it does**: Converts your text prompts into something the AI can understand
# - **GitHub**: [github.com/huggingface/transformers](https://github.com/huggingface/transformers)
# - **Think of it as**: The "translator" between English and AI language
# - **Used by**: Major tech companies worldwide
#
# **⚡ `accelerate`**
# - **Purpose**: Makes AI models run faster and more efficiently
# - **What it does**: Optimizes performance for different hardware (CPU, GPU)
# - **GitHub**: [github.com/huggingface/accelerate](https://github.com/huggingface/accelerate)
# - **Think of it as**: The "turbo boost" for AI processing
# - **Supports**: CPU, GPU, and distributed computing
#
# **🔒 `safetensors`**
# - **Purpose**: Secure way to store and load AI models
# - **What it does**: Ensures models are loaded safely and efficiently
# - **GitHub**: [github.com/huggingface/safetensors](https://github.com/huggingface/safetensors)
# - **Think of it as**: The "secure storage" for AI model files
# - **Security**: Prevents malicious code in model files
#
#
# #### **All Libraries Developed by Hugging Face**
# 🤗 **Hugging Face Explained**
# - **What it is**: Hugging Face is like the "GitHub for AI" - a platform where AI researchers and developers share their models
# - **Think of it as**: A huge library of AI models that anyone can use for free
# - **Founded by**: Clément Delangue and Julien Chaumond in 2016
# - **Mission**: Democratizing AI by making state-of-the-art models accessible to everyone
# - **Website**: [huggingface.co](https://huggingface.co)
#
# 🌟 **Why This Ecosystem Matters:**
# - **Free Access**: All tools are open-source and free
# - **Professional Grade**: Used by major tech companies
# - **Community Driven**: Thousands of contributors worldwide
# - **Easy to Use**: Simple Python commands for powerful AI
#
# **Real Impact**: Instead of spending months building AI tools, we can use these professional-grade libraries in minutes! 🚀
#
# </details>

# %% [markdown]
# ---
#
# ## 🧩 Step 3: Load the Libraries and Check the GPU
# Now, we’ll import everything and check if your system (or cloud environment) has a GPU available.

# %%
import torch, os
from diffusers import AutoPipelineForText2Image
print('✅ Setup complete. GPU available:', torch.cuda.is_available())

# %% [markdown]
# <details>
# <summary>📝 What does this code do? (Click to Expand)</summary>
#
# Let's break down each line of code:
#
# ```python
# import torch, os
# ```
# - **torch** = PyTorch library for deep learning and AI
# - **os** = Operating system interface (for file paths, environment variables)
# - This imports the core AI framework and system tools
#
# ```python
# from diffusers import AutoPipelineForText2Image
# ```
# - **diffusers** = Hugging Face's library for AI image generation
# - **AutoPipelineForText2Image** = A pre-built pipeline for text-to-image generation
# - This gives us the AI model that creates images from text
#
# ```python
# print('✅ Setup complete. GPU available:', torch.cuda.is_available())
# ```
# - **torch.cuda.is_available()** = Checks if your computer has a GPU
# - **GPU** = Graphics Processing Unit (makes AI run much faster)
# - This tells us whether we can use fast GPU acceleration
#
#
# ---
# 🏭 **What is a "Pipeline"?**
# - **Pipeline** = A ready-to-use AI system that handles all the complex steps automatically
# - **Think of it as**: Like a factory assembly line - you put text in one end, and get an image out the other end
# - **Why it's helpful**: Instead of building everything from scratch, we get a complete working system
# - **AutoPipelineForText2Image** = Specifically designed to turn text descriptions into images
# </details>

# %% [markdown]
# <details>
# <summary>📚 Where do these libraries come from? (Click to Expand)</summary>
#
# #### 🧠 **PyTorch (torch)**
# - **Developer**: Meta (Facebook) AI Research
# - **Location**: [pytorch.org](https://pytorch.org)
# - **Purpose**: Deep learning framework - the "brain" of AI
# - **Why we need it**: Powers all the AI calculations and GPU acceleration
#
# #### 🖥️ **OS (Operating System)**
# - **Developer**: Python Software Foundation
# - **Location**: Built into Python
# - **Purpose**: System interface for file operations
# - **Why we need it**: Handles file paths and system interactions
#
# #### 🎨 **Diffusers**
# - **Developer**: Hugging Face
# - **Location**: [github.com/huggingface/diffusers](https://github.com/huggingface/diffusers)
# - **Purpose**: AI image generation models (Stable Diffusion, etc.)
# - **Why we need it**: Provides the actual image generation capabilities
#
# #### ⚡ **CUDA (GPU Support)**
# - **Developer**: NVIDIA
# - **Location**: [developer.nvidia.com/cuda](https://developer.nvidia.com/cuda)
# - **Purpose**: GPU acceleration for AI computations
# - **Why we need it**: Makes image generation 10-100x faster
#
# **The Ecosystem**: These libraries work together to create a complete AI image generation system! 🤖
# </details>

# %% [markdown]
# ---
#
# ## 🧠 Step 4: Load the AI Model
# We’ll use a smaller, faster version of *Stable Diffusion* called **SD Turbo**. It’s designed for quick image generation, perfect for workshops!

# %%
model_id = 'stabilityai/sd-turbo'
pipe = AutoPipelineForText2Image.from_pretrained(model_id, torch_dtype=torch.float16).to('cuda' if torch.cuda.is_available() else 'cpu')
print('🎨 Model loaded and ready!')

# %% [markdown]
# <details>
# <summary>🎨 What does this model loading code do?</summary>
#
# Let's break down each line of code:
#
# ```python
# model_id = 'stabilityai/sd-turbo'
# ```
# - **model_id** = A variable that stores the name of the AI model we want to use
# - **'stabilityai/sd-turbo'** = The specific model name
#   - **stabilityai** = The company that created this model (Stability AI)
#   - **sd-turbo** = "Stable Diffusion Turbo" - a faster version of Stable Diffusion
# - **Think of it as**: Choosing which "AI artist" we want to work with
#
# ```python
# pipe = AutoPipelineForText2Image.from_pretrained(model_id, torch_dtype=torch.float16).to('cuda' if torch.cuda.is_available() else 'cpu')
# ```
# This is a complex line, let's break it down:
#
# - **pipe** = Our AI image generation "pipeline" (the complete system)
# - **AutoPipelineForText2Image** = The Hugging Face class for text-to-image generation
# - **from_pretrained(model_id)** = Download and load the model from Hugging Face
# - **torch_dtype=torch.float16** = Use 16-bit precision (faster and uses less memory)
# - **.to('cuda' if torch.cuda.is_available() else 'cpu')** = Move the model to GPU if available, otherwise use CPU
#
# **In simple terms**: We're downloading a pre-trained AI model and setting it up to run on the best available hardware!
#
# ```python
# print('🎨 Model loaded and ready!')
# ```
# - **print()** = Display a message to confirm everything worked
# - **🎨 Model loaded and ready!** = Success message telling us the AI is ready to create images
#
# </details>
#
#
# <details>
# <summary>🌍 Learn about the company behind Stable Diffusion</summary>
#
# #### 🏢 **Stability AI**
# - **Company**: Stability AI Ltd.
# - **Founded**: 2020 by Emad Mostaque
# - **Mission**: "AI by the people, for the people" - democratizing AI technology
# - **Website**: [stability.ai](https://stability.ai)
#
# #### 🎨 **Stable Diffusion**
# - **What it is**: One of the most popular AI image generation models
# - **Open Source**: Released publicly in 2022
# - **Impact**: Made AI image generation accessible to everyone
# - **SD Turbo**: Faster version optimized for real-time generation
#
# #### 🌟 **Why This Matters**
# - **Free Access**: Stable Diffusion is open-source and free to use
# - **Community**: Thousands of developers have built on top of it
# - **Innovation**: Led to explosion of AI art tools and applications
# - **Democratization**: Put powerful AI in hands of regular users
#
# #### 🚀 **Technical Details**
# - **Model Size**: ~4GB (relatively small for AI models)
# - **Speed**: SD Turbo generates images in ~1 second
# - **Quality**: High-quality, realistic images
# - **Hardware**: Works on consumer GPUs (not just supercomputers)
#
# **Real Impact**: Stability AI helped make AI image generation mainstream and accessible! 🎯
#
# </details>

# %% [markdown]
# ---
#
# ## 🖼️ Step 5: Generate Your First Image
# Let’s make AI draw something from your words! Try running the cell below.

# %%
prompt = "a cute robot painting a sunset, digital art"
image = pipe(prompt).images[0]
plt.imshow(image)
plt.axis('off')
plt.title("AI-Generated Demo Image 🌅")
plt.show()

# %% [markdown]
# <details>
# <summary>🎨 What does this image generation code do? (Click to expand)</summary>
#
# Let's break down each line of code:
#
# ```python
# prompt = "a cute robot painting a sunset, digital art"
# ```
# - **prompt** = A variable that stores your text description
# - **"a cute robot painting a sunset, digital art"** = The specific description we want the AI to create
# - **Think of it as**: Giving instructions to our AI artist about what to paint
#
# ```python
# image = pipe(prompt).images[0]
# ```
# This line does the actual AI magic:
#
# - **pipe(prompt)** = Send our text prompt to the AI model
# - **pipe** = Our AI image generation system (from Step 4)
# - **.images[0]** = Get the first (and only) generated image
# - **image** = Store the result in a variable
# - **Think of it as**: The AI "painting" our image based on our instructions
#
# ```python
# plt.imshow(image)
# ```
# - **plt** = Matplotlib library for displaying images
# - **imshow()** = Function to display an image
# - **image** = The AI-generated image we want to show
# - **Think of it as**: Putting the image on a canvas to display
#
# ```python
# plt.axis('off')
# ```
# - **axis('off')** = Remove the axis lines and numbers around the image
# - **Why?** Makes the image look cleaner without technical details
# - **Think of it as**: Removing the frame around a picture
#
# ```python
# plt.title("AI-Generated Demo Image 🌅")
# ```
# - **title()** = Add a title above the image
# - **"AI-Generated Demo Image 🌅"** = The title text with a sunset emoji
# - **Think of it as**: Adding a label to identify what the image is
#
# ```python
# plt.show()
# ```
# - **show()** = Actually display the image on screen
# - **This is the final step** that makes the image visible
# - **Think of it as**: Showing the finished artwork to the audience
#
# </details>
#
#
# <details>
# <summary>📊 bout Matplotlib: Learn about the visualization library we're using (Click to expand)</summary>
#
# #### 📊 **What is Matplotlib?**
# - **Library**: Matplotlib (short for "mathematical plotting library")
# - **Purpose**: Creates graphs, charts, and displays images
# - **Developer**: John D. Hunter (2003)
# - **Website**: [matplotlib.org](https://matplotlib.org)
#
# #### 🎨 **Why We Use It for Images**
# - **Image Display**: Perfect for showing AI-generated images
# - **Customization**: Can add titles, remove axes, format images
# - **Integration**: Works seamlessly with Jupyter notebooks
# - **Professional**: Used by scientists, engineers, and data scientists
#
# #### 🔧 **Common Functions We Use**
# - **plt.imshow()** = Display images
# - **plt.axis('off')** = Remove axis lines for cleaner look
# - **plt.title()** = Add titles above images
# - **plt.show()** = Actually display the image
#
# #### 🌟 **Why This Matters**
# - **Visualization**: Essential for seeing AI results
# - **Professional**: Industry-standard tool for data visualization
# - **Flexible**: Can customize how images are displayed
# - **Educational**: Helps students understand data visualization
#
# **Real Impact**: Matplotlib makes it easy to display and share AI-generated images! 📈
#
# </details>

# %% [markdown]
# ✅ **Try it yourself:** Change the text in the quotes to something else! For example:
# - `a flying car over the ocean at sunset`
# - `a futuristic classroom with friendly robots`
# - `a golden retriever astronaut on Mars`

# %% [markdown]
# ---
#
# ## 🧩 Step 6: Try Multiple Prompts
# Let’s create several images automatically using a list of prompts.

# %%
prompts = [
    'pixel art dragon, bright colors',
    'robot mentor with laptop, in a classroom',
    'magic sword on pedestal, glowing in dark room'
]

for i, text in enumerate(prompts):
    print(f'Generating image {i+1}:', text)
    image = pipe(text).images[0]
    image.show()

# %% [markdown]
# <details>
# <summary>🎨 What does this batch image generation code do? (Click to expand)</summary>
#
# Let's break down each part of the code:
#
# ```python
# prompts = [
#     'pixel art dragon, bright colors',
#     'robot mentor with laptop, in a classroom',
#     'magic sword on pedestal, glowing in dark room'
# ]
# ```
# - **prompts** = A list (array) that stores multiple text descriptions
# - **List format** = Square brackets `[]` contain multiple items separated by commas
# - **Three prompts** = Three different images we want to generate
# - **Think of it as**: A shopping list of images we want the AI to create
#
# ```python
# for i, text in enumerate(prompts):
# ```
# This line starts a loop that processes each prompt:
#
# - **for** = Start a loop (repeat something multiple times)
# - **i, text** = Two variables: `i` for the number, `text` for the prompt
# - **enumerate(prompts)** = Go through each item in the prompts list
# - **Think of it as**: Going through each item on our shopping list one by one
#
# ```python
# print(f'Generating image {i+1}:', text)
# ```
# - **print()** = Display a message
# - **f'Generating image {i+1}:'** = Show which image number we're creating (1, 2, 3)
# - **text** = Show the actual prompt being used
# - **Think of it as**: Announcing what we're about to create
#
# ```python
# image = pipe(text).images[0]
# ```
# - **Same as Step 5** = Generate an image from the text prompt
# - **pipe(text)** = Send the current prompt to the AI
# - **.images[0]** = Get the generated image
# - **image** = Store the result
# - **Think of it as**: The AI creating each image from our list
#
# ```python
# image.show()
# ```
# - **image.show()** = Display the image directly (simpler than matplotlib)
# - **Built-in method** = PIL images have their own display function
# - **Think of it as**: Showing each finished artwork
#
# </details>
#
#
# <details>
# <summary>📚 Learn about programming concepts we're using (Click to expand)</summary>
#
# #### 📝 **What is a List?**
# - **Definition**: A collection of items stored together
# - **Syntax**: Square brackets `[]` with items separated by commas
# - **Example**: `['apple', 'banana', 'orange']`
# - **Why useful**: Store multiple related items in one variable
#
# #### 🔄 **What is a Loop?**
# - **Definition**: Code that repeats multiple times
# - **Types**: `for` loops (repeat a specific number of times)
# - **Why useful**: Avoid writing the same code over and over
# - **Example**: Instead of 3 separate image generation commands, we use 1 loop
#
# #### 🔢 **What is enumerate()?**
# - **Purpose**: Get both the position number and the item from a list
# - **Example**: `enumerate(['a', 'b', 'c'])` gives us `(0, 'a')`, `(1, 'b')`, `(2, 'c')`
# - **Why useful**: Know which item we're processing (1st, 2nd, 3rd, etc.)
#
# #### 🎨 **Why This Approach is Better**
# - **Efficiency**: Generate multiple images with one code block
# - **Organization**: Keep all prompts together in one place
# - **Scalability**: Easy to add more prompts to the list
# - **Professional**: This is how real AI applications work
#
# #### 🌟 **Real-World Applications**
# - **Batch Processing**: Generate multiple images at once
# - **A/B Testing**: Try different prompts to see which works best
# - **Content Creation**: Generate variations of the same concept
# - **Automation**: Process large numbers of images automatically
#
# **Real Impact**: This pattern is used in professional AI applications for efficient batch processing! 🚀
#
# </details>

# %% [markdown]
# ---
#
# ## 🎨 Step 7: Your Turn — Create Your Own Prompts!
# Now it’s your time to get creative! ✨
# Come up with 3–5 of your own prompts. Think of art styles like *cartoon, watercolor, futuristic, pixel art*, etc.

# %%
my_prompts = [
    'cartoon astronaut exploring candy planet',
    'pixel art robot chef cooking ramen',
    'AI superhero flying through neon city'
]

for i, text in enumerate(my_prompts):
    print(f'🎨 Creating: {text}')
    image = pipe(text).images[0]
    image.save(f'my_image_{i}.png')
    image.show()

# %% [markdown]
# ---
#
# ## 💾 Step 8: Save Your Creations
# Let’s save all your artworks in a folder so you can use them later in your AI Guessing Game.

# %%
# !mkdir -p my_game_assets
for i, text in enumerate(my_prompts):
    path = f'my_game_assets/asset_{i}.png'
    pipe(text).images[0].save(path)
print('✅ All images saved to the folder: my_game_assets/')

# %% [markdown]
# <details>
# <summary>💾 What does this image saving code do? (Click to expand)
# </summary>
#
# Let's break down each line of code:
#
# ```python
# !mkdir -p my_game_assets
# ```
# - **`!`** = Tells Jupyter to run this as a system command (not Python code)
# - **mkdir** = "Make directory" - create a new folder
# - **-p** = Create parent directories if they don't exist (no error if folder already exists)
# - **my_game_assets** = The name of the folder we're creating
# - **Think of it as**: Creating a new folder to store our images
#
# ```python
# for i, text in enumerate(my_prompts):
# ```
# - **Same as Step 6** = Loop through each prompt in the list
# - **my_prompts** = The list of prompts we defined earlier
# - **i, text** = Get the number and prompt text
# - **Think of it as**: Going through each image we want to save
#
# ```python
# path = f'my_game_assets/asset_{i}.png'
# ```
# - **path** = Variable that stores the file path where we'll save the image
# - **f'my_game_assets/asset_{i}.png'** = Create a filename using f-string formatting
#   - **my_game_assets/** = The folder we created
#   - **asset_** = Part of the filename
#   - **{i}** = The number (0, 1, 2, etc.)
#   - **.png** = The file format (Portable Network Graphics)
# - **Examples**: `asset_0.png`, `asset_1.png`, `asset_2.png`
# - **Think of it as**: Creating a unique filename for each image
#
# ```python
# pipe(text).images[0].save(path)
# ```
# This line generates and saves the image:
#
# - **pipe(text)** = Generate image from the prompt (same as before)
# - **.images[0]** = Get the first generated image
# - **.save(path)** = Save the image to the specified file path
# - **Think of it as**: Creating the image and putting it in the right folder with the right name
#
# ```python
# print('✅ All images saved to the folder: my_game_assets/')
# ```
# - **print()** = Display a success message
# - **✅** = Checkmark emoji to show success
# - **Message** = Confirms all images were saved
# - **Think of it as**: Confirming the job is done
#
# </details>
#
#
# <details>
# <summary>📁 Learn about saving files and organizing data (Click to expand)</summary>
#
# #### 📁 **What is a Directory/Folder?**
# - **Definition**: A container that holds files and other folders
# - **Purpose**: Organize files so they're easy to find
# - **Example**: Like a filing cabinet with different drawers
# - **Why important**: Keeps your project organized
#
# #### 💾 **What is File Saving?**
# - **Definition**: Storing data permanently on your computer
# - **Purpose**: Keep your work so you can use it later
# - **Format**: PNG is a common image format that preserves quality
# - **Why important**: Without saving, your work disappears when you close the program
#
# #### 🔢 **What is f-string Formatting?**
# - **Syntax**: `f'text {variable} more text'`
# - **Purpose**: Insert variables into text strings
# - **Example**: `f'Hello {name}'` becomes `'Hello John'` if name='John'
# - **Why useful**: Create dynamic filenames and messages
#
# #### 📝 **File Naming Conventions**
# - **asset_0.png, asset_1.png, asset_2.png** = Clear, organized naming
# - **Numbers** = Easy to identify order and count
# - **Descriptive** = Know what type of files these are
# - **Consistent** = Same pattern for all files
#
# #### 🎮 **Why This Matters for Game Development**
# - **Asset Management**: Games need organized image files
# - **Batch Processing**: Generate multiple assets at once
# - **Automation**: Save time by automating file creation
# - **Professional**: This is how real game developers work
#
# #### 🌟 **Real-World Applications**
# - **Game Development**: Create character sprites, backgrounds, items
# - **Web Design**: Generate multiple website images
# - **Marketing**: Create variations of product images
# - **Content Creation**: Batch generate social media images
#
# **Real Impact**: This pattern is essential for any project that needs multiple image files! 🎯
#
# </details>

# %% [markdown]
# ---
#
# ## 🧭 Wrap-Up & Reflection
# 🎉 You just used AI to generate art from your imagination!
#
# **Discuss:**
# - Which prompt gave the best result?
# - How can you describe things more clearly for better results?
# - How might this be useful for your future AI game?

# %% [markdown]
# ---
# ## 🧩 Extra Challenges – Explore More with AI 🎨
#
# > 📝 *This section is optional and meant for independent exploration after the session.*
# > Try these exercises if you finish early or want to explore AI art generation further.

# %% [markdown]
# ### 🧠 Challenge 1: Prompt Engineering (~5–7 min)
# Experiment with how *small changes* in wording affect the image output.
# Example:
# ```python
# prompt = "a cat"
# prompt = "a cartoon cat"
# prompt = "a cartoon cat wearing sunglasses"
# ```
# **Question:** Which words made the biggest difference? Why do you think so?

# %% [markdown]
# ### 🧠 Challenge 2: Style Experiments (~7–10 min)
# Add art style keywords such as `"pixel art"`, `"watercolor"`, or `"oil painting"`.
# **Task:** Try the same subject with three different art styles.
# **Question:** Which style looked most natural or most creative?

# %% [markdown]
# ### 🧠 Challenge 3: Randomness and Seeds (~7–10 min)
# Learn how randomness affects AI output. Use a fixed seed for reproducibility:
#
# **Task:** Change the seed number (e.g., 7, 21, 99).

# %%
import torch
generator = torch.manual_seed(42)
image = pipe("a futuristic classroom", generator=generator).images[0]
image.show()
```

# %% [markdown]
# **Question:** How does the same prompt differ with different seeds?

# %% [markdown]
# ### 🧠 Challenge 4: AI Ethics and Data (~5–10 min)
# Discuss or research:
# - Where does AI art data come from?
# - Why might artists be concerned about copyright or bias?
#
# **Task:** Write 3 sentences summarizing your thoughts.

# %% [markdown]
# ### 🧠 Challenge 5: Mini Creative Project (~10–15 min)
# Create your own small project using AI-generated images!
# Ideas:
# - A short slideshow of your generated images
# - A “guess the prompt” mini-game
# - A themed art collection (e.g., “AI Pets” or “Future Gadgets”)
#
# **Goal:** Combine creativity and coding skills.

# %% [markdown]
# ---
# ## 🪞 Reflection – What Did You Learn Today?
# Take a few minutes to reflect on today’s lesson. You can write your answers here or discuss them with a partner.
#
# - What surprised you most about how AI creates images?
# - Which part did you enjoy most — writing prompts or seeing results?
# - How might you use AI image generation in real life or school projects?
# - What would you like to learn next about AI?

# %% [markdown]
# ---
#
# # 🌐 Additional Resources & Further Learning
#
# ## 🎨 AI Image & Video Creation Websites
#
# <details>
# <summary><strong>🖼️ Free AI Image Generators</strong></summary>
#
# - **[DALL-E 2](https://openai.com/dall-e-2)** - OpenAI's image generator (requires account)
# - **[Midjourney](https://midjourney.com)** - High-quality artistic images (Discord-based)
# - **[Stable Diffusion Web](https://stablediffusionweb.com)** - Free online Stable Diffusion
# - **[Craiyon](https://craiyon.com)** - Free AI image generator (formerly DALL-E Mini)
# - **[Bing Image Creator](https://www.bing.com/images/create)** - Microsoft's free AI image tool
#
# </details>
#
# <details>
# <summary><strong>🎬 AI Video Creation Tools</strong></summary>
#
# - **[Runway ML](https://runwayml.com)** - AI video editing and generation
# - **[Pika Labs](https://pika.art)** - Text-to-video generation
# - **[Synthesia](https://www.synthesia.io)** - AI video avatars
# - **[Luma AI](https://lumalabs.ai)** - 3D capture and AI video
#
# </details>
#
# <details>
# <summary><strong>🎮 Game-Specific AI Tools</strong></summary>
#
# - **[Scenario](https://www.scenario.com)** - AI for game asset generation
# - **[Artbreeder](https://www.artbreeder.com)** - Mix and create game characters
# - **[This Person Does Not Exist](https://thispersondoesnotexist.com)** - Generate realistic faces
#
# </details>
#
#
# ## 📚 Further Learning Resources
#
# <details>
# <summary><strong>📖 Books & Articles</strong></summary>
#
# - **"AI and Machine Learning for Coders"** by Laurence Moroney
# - **"Hands-On Machine Learning"** by Aurélien Géron
# - **"Deep Learning"** by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# - **"The Master Algorithm"** by Pedro Domingos
#
# </details>
#
# <details>
# <summary><strong>🎓 Online Courses</strong></summary>
#
# - **[Coursera - Machine Learning](https://www.coursera.org/learn/machine-learning)** - Andrew Ng's famous course
# - **[edX - Introduction to AI](https://www.edx.org/course/introduction-to-artificial-intelligence-ai)** - MIT course
# - **[Udacity - AI Programming with Python](https://www.udacity.com/course/ai-programming-python-nanodegree)** - Nanodegree program
# - **[Fast.ai](https://www.fast.ai)** - Practical deep learning courses
#
# </details>
#
# <details>
# <summary><strong>🛠️ Technical Resources</strong></summary>
#
# - **[Hugging Face Course](https://huggingface.co/course)** - Free NLP and AI course
# - **[PyTorch Tutorials](https://pytorch.org/tutorials/)** - Official PyTorch learning materials
# - **[TensorFlow Tutorials](https://www.tensorflow.org/tutorials)** - Google's ML framework tutorials
# - **[OpenAI API Documentation](https://platform.openai.com/docs)** - Learn to use OpenAI's APIs
#
# </details>
#
# <details>
# <summary><strong>🎨 Creative AI Communities</strong></summary>
#
# - **[r/MachineLearning](https://reddit.com/r/MachineLearning)** - Reddit community
# - **[AI Art Community](https://discord.gg/ai-art)** - Discord server for AI artists
# - **[Hugging Face Community](https://huggingface.co/community)** - Model sharing and discussions
# - **[GitHub AI Projects](https://github.com/topics/artificial-intelligence)** - Open source AI projects
#
# </details>
#
# <details>
# <summary><strong>🔬 Research & News</strong></summary>
#
# - **[ArXiv](https://arxiv.org/list/cs.AI/recent)** - Latest AI research papers
# - **[AI News](https://www.artificialintelligence-news.com)** - AI industry news
# - **[The Gradient](https://thegradient.pub)** - AI research blog
# - **[Towards Data Science](https://towardsdatascience.com)** - Medium publication on AI/ML
#
# </details>
#
# <details>
# <summary><strong>🎯 Specialized Topics</strong></summary>
#
# - **Computer Vision**: Learn about image recognition and processing
# - **Natural Language Processing**: Understand how AI processes text
# - **Generative AI**: Deep dive into creating content with AI
# - **AI Ethics**: Learn about responsible AI development
# - **Neural Networks**: Understand the math behind AI
#
# </details>
#
#
# **Remember**: AI is a tool to enhance your creativity, not replace it. The best results come from combining AI capabilities with human imagination and judgment! 🎨✨
